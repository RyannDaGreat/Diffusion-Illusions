# %%
gpu='cuda:0'

prompt_structure='a beautiful award-winning royalty-free full-frame stock photo of an isolated '
prompt_structure='an award winning photo of a %s'

prompt_sets=[
    [
        prompt_structure%"cow",
        prompt_structure%"motorbike",
        prompt_structure%"chair",
        prompt_structure%"train",
        prompt_structure%"bird"
    ],
    [
        prompt_structure%"horse",
        prompt_structure%"bottle",
        prompt_structure%"dog",
        prompt_structure%"sofa",
        prompt_structure%"tv monitor"
    ],
    [
        prompt_structure%"cat",
        prompt_structure%"dining table",
        prompt_structure%"car",
        prompt_structure%"aeroplane",
        prompt_structure%"sheep"
    ],
    [
        prompt_structure%"motorbike",
        prompt_structure%"train",
        prompt_structure%"bus",
        prompt_structure%"tv monitor",
        prompt_structure%"dog"
    ],
    [
        prompt_structure%"train",
        prompt_structure%"person",
        prompt_structure%"sheep",
        prompt_structure%"dining table",
        prompt_structure%"sofa"
    ],
    [
        prompt_structure%"potted plant",
        prompt_structure%"horse",
        prompt_structure%"bicycle",
        prompt_structure%"motorbike",
        prompt_structure%"cat"
    ],
    [
        prompt_structure%"boat",
        prompt_structure%"dog",
        prompt_structure%"dining table",
        prompt_structure%"bus",
        prompt_structure%"cow"
    ],
    [
        prompt_structure%"bottle",
        prompt_structure%"tv monitor",
        prompt_structure%"motorbike",
        prompt_structure%"cat",
        prompt_structure%"bicycle"
    ],
    [
        prompt_structure%"dining table",
        prompt_structure%"aeroplane",
        prompt_structure%"horse",
        prompt_structure%"boat",
        prompt_structure%"motorbike"
    ],
    [
        prompt_structure%"bird",
        prompt_structure%"car",
        prompt_structure%"cat",
        prompt_structure%"horse",
        prompt_structure%"person"
    ],
    [
        prompt_structure%"chair",
        prompt_structure%"bird",
        prompt_structure%"tv monitor",
        prompt_structure%"dog",
        prompt_structure%"aeroplane"
    ],
    [
        prompt_structure%"car",
        prompt_structure%"cat",
        prompt_structure%"bird",
        prompt_structure%"bottle",
        prompt_structure%"horse"
    ],
    [
        prompt_structure%"sofa",
        prompt_structure%"boat",
        prompt_structure%"potted plant",
        prompt_structure%"person",
        prompt_structure%"chair"
    ],
    [
        prompt_structure%"bicycle",
        prompt_structure%"chair",
        prompt_structure%"train",
        prompt_structure%"sheep",
        prompt_structure%"boat"
    ],
    [
        prompt_structure%"bus",
        prompt_structure%"cow",
        prompt_structure%"boat",
        prompt_structure%"car",
        prompt_structure%"potted plant"
    ],
    [
        prompt_structure%"person",
        prompt_structure%"bicycle",
        prompt_structure%"bottle",
        prompt_structure%"bird",
        prompt_structure%"bus"
    ],
    [
        prompt_structure%"aeroplane",
        prompt_structure%"sheep",
        prompt_structure%"cow",
        prompt_structure%"chair",
        prompt_structure%"car"
    ],
    [
        prompt_structure%"dog",
        prompt_structure%"sofa",
        prompt_structure%"aeroplane",
        prompt_structure%"potted plant",
        prompt_structure%"bottle"
    ],
    [
        prompt_structure%"sheep",
        prompt_structure%"bus",
        prompt_structure%"person",
        prompt_structure%"bicycle",
        prompt_structure%"train"
    ],
    [
        prompt_structure%"tv monitor",
        prompt_structure%"potted plant",
        prompt_structure%"sofa",
        prompt_structure%"cow",
        prompt_structure%"dining table"
    ],
]

# %%
from rp import *
base_notebook_path = "/workspace/Diffusion-Illusions/hidden_characters_miku_borealis_new_regular.ipynb"
base_notebook_code = extract_code_from_ipynb(base_notebook_path)
seed_nummy=rp.random_int(0,1000000)

# %%
HEADLESS=False #Borealis is a SINGLE configuration.

for trial_num in range(10000):
    trial_num+=0 #So we can preview one of the algos faster
    
    prompt_a, prompt_b, prompt_c, prompt_d, prompt_z = prompt_sets[trial_num%len(prompt_sets)]
    
    import icecream
    icecream.ic(prompt_a,prompt_b,prompt_c,prompt_d,prompt_z)
    
    #################################################################
    
    rp.exeval(base_notebook_code)
