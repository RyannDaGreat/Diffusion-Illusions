# %%
gpu='cuda:3'

prompt_sets=[
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated horse",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bottle",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated dog",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated sofa",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated television"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated cat",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated dining table",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated car",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated aeroplane",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated sheep"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated cow",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated motorbike",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated chair",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated train",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bird"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated motorbike",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated train",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bus",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated television",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated dog"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated train",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated person",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated sheep",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated dining table",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated sofa"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated potted plant",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated horse",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bicycle",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated motorbike",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated cat"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated boat",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated dog",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated dining table",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bus",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated cow"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bottle",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated television",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated motorbike",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated cat",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bicycle"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated dining table",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated aeroplane",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated horse",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated boat",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated motorbike"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bird",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated car",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated cat",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated horse",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated person"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated chair",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bird",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated television",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated dog",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated aeroplane"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated car",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated cat",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bird",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bottle",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated horse"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated sofa",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated boat",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated potted plant",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated person",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated chair"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bicycle",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated chair",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated train",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated sheep",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated boat"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bus",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated cow",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated boat",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated car",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated potted plant"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated person",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bicycle",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bottle",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bird",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bus"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated aeroplane",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated sheep",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated cow",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated chair",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated car"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated dog",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated sofa",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated aeroplane",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated potted plant",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bottle"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated sheep",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bus",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated person",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated bicycle",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated train"
    ],
    [
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated television",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated potted plant",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated sofa",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated cow",
        "a beautiful award-winning royalty-free full-frame stock photo of an isolated dining table"
    ],
]


prompt_sets=prompt_sets[::-1]

# %%
from rp import *
base_notebook_path = "/workspace/Diffusion-Illusions/hidden_characters_for_colab__advanced_miku_BASE_borealis.ipynb"
base_notebook_code = extract_code_from_ipynb(base_notebook_path)
seed_nummy=rp.random_int(0,1000000)

# %%
HEADLESS=False #Borealis is a SINGLE configuration.

for trial_num in range(10000):
    trial_num+=0 #So we can preview one of the algos faster
    
    prompt_a, prompt_b, prompt_c, prompt_d, prompt_z = prompt_sets[trial_num%len(prompt_sets)]
    
    import icecream
    icecream.ic(prompt_a,prompt_b,prompt_c,prompt_d,prompt_z)
    
    #################################################################
    
    rp.exeval(base_notebook_code)
